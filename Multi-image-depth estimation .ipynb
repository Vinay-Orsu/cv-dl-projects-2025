# %%
# !brew install colmap
# Out:
# ==> Downloading https://formulae.brew.sh/api/formula.jws.json
# ==> Downloading https://formulae.brew.sh/api/cask.jws.json
# ==> Fetching downloads for: colmap
# ==> Downloading https://ghcr.io/v2/homebrew/core/colmap/manifests/3.12.3
# ######################################################################### 100.0%
# ==> Fetching dependencies for colmap: openblas, libomp, tbb, cgal, faiss, libaec, pkgconf, poselib, libpng, gettext, glib, jpeg-turbo, readline and sqlite
# ==> Downloading https://ghcr.io/v2/homebrew/core/openblas/manifests/0.3.30
# ######################################################################### 100.0%
# ==> Fetching openblas
# ==> Downloading https://ghcr.io/v2/homebrew/core/openblas/blobs/sha256:19429463a
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libomp/manifests/20.1.8
# ######################################################################### 100.0%
# ...

# %%
import cv2
import time
import os

# %%
cap = cv2.VideoCapture(0)
for i in range(10):
    ret, frame = cap.read()
    cv2.imwrite(f"view_{i:02d}.jpg", frame)
    time.sleep(1.5)

# %%
# Out:
#   Cell In[11], line 1
#     colmap automatic_reconstructor \
#            ^
# SyntaxError: invalid syntax
